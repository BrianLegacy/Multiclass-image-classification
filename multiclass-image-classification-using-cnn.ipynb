# %% [markdown]
# # <p style="text-align: center;">Multiclass Image Classification Using CNN</p>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %% [markdown]
# ### **2. Load the Image Training and Validation Datasets**

# %% [markdown]
# #### **i. Get the Image Dataset Paths**

# %%
train_dataset_path = '/kaggle/input/intel-image-classification/seg_train/seg_train/'
validation_dataset_path = '/kaggle/input/intel-image-classification/seg_test/seg_test/'

# %% [markdown]
# #### **ii. Load Image Datasets and Apply Augmentations**

# %%
IMG_WIDTH = 150
IMG_HEIGHT = 150
BATCH_SIZE = 32

# %% [markdown]
# Loading the training dataset and applying augmentations on it.

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 14034 images belonging to 6 classes.

# %% [markdown]
# Loading the validation dataset.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 3000 images belonging to 6 classes.

# %% [markdown]
# #### **iii. Get the Label Mappings**

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : buildings
# 1 : forest
# 2 : glacier
# 3 : mountain
# 4 : sea
# 5 : street

# %% [markdown]
# ### **3. Plotting Sample Training Images**

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %% [markdown]
# ### **4. Training a CNN Model**

# %% [markdown]
# #### **i. Create a CNN Model**

# %%
def create_model():
    model = Sequential([
        Conv2D(filters=128, kernel_size=(5, 5), padding='valid', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Conv2D(filters=64, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Conv2D(filters=32, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Flatten(),
        
        Dense(units=256, activation='relu'),
        Dropout(0.5),
        Dense(units=6, activation='softmax')
    ])
    
    return model

# %%
cnn_model = create_model()

# %%
print(cnn_model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 146, 146, 128)     9728
# _________________________________________________________________
# activation (Activation)      (None, 146, 146, 128)     0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 73, 73, 128)       0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 73, 73, 128)       512
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 71, 71, 64)        73792
# _________________________________________________________________
# activation_1 (Activation)    (None, 71, 71, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 35, 35, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 35, 35, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 33, 33, 32)        18464
# _________________________________________________________________
# activation_2 (Activation)    (None, 33, 33, 32)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2097408
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 1542
# =================================================================
# Total params: 2,201,830
# Trainable params: 2,201,382
# Non-trainable params: 448
# _________________________________________________________________
# None

# %% [markdown]
# #### **a. Reduce Learning Rate on Plateau**
#
# Is used to reduce the learning rate when a metric has stopped improving.

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)

# %% [markdown]
# #### **iii. Defining the Optimizer**

# %%
optimizer = Adam(learning_rate=0.001)

# %% [markdown]
# #### **iv. Compile the Model**

# %%
cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])

# %% [markdown]
# #### **v. Training the Model**

# %%
history = cnn_model.fit(train_generator, epochs=50, validation_data=validation_generator,
                       verbose=2,
                       callbacks=[reduce_lr])
# Out:
# Epoch 1/50
# 439/439 - 162s - loss: 1.9649 - accuracy: 0.5016 - val_loss: 1.7999 - val_accuracy: 0.4703
# Epoch 2/50
# 439/439 - 88s - loss: 1.0837 - accuracy: 0.5990 - val_loss: 0.9164 - val_accuracy: 0.6897
# Epoch 3/50
# 439/439 - 89s - loss: 0.9168 - accuracy: 0.6657 - val_loss: 0.8411 - val_accuracy: 0.6923
# Epoch 4/50
# 439/439 - 88s - loss: 0.8575 - accuracy: 0.6909 - val_loss: 2.0568 - val_accuracy: 0.4110
# Epoch 5/50
# 439/439 - 88s - loss: 0.7845 - accuracy: 0.7204 - val_loss: 3.3576 - val_accuracy: 0.4203
# Epoch 6/50
# 439/439 - 90s - loss: 0.7217 - accuracy: 0.7462 - val_loss: 0.9237 - val_accuracy: 0.7297
# Epoch 7/50
# 439/439 - 89s - loss: 0.6976 - accuracy: 0.7529 - val_loss: 0.5417 - val_accuracy: 0.8193
# Epoch 8/50
# 439/439 - 88s - loss: 0.6598 - accuracy: 0.7683 - val_loss: 0.6057 - val_accuracy: 0.7917
# Epoch 9/50
# 439/439 - 89s - loss: 0.6487 - accuracy: 0.7748 - val_loss: 0.7230 - val_accuracy: 0.7503
# Epoch 10/50
# 439/439 - 88s - loss: 0.6349 - accuracy: 0.7764 - val_loss: 0.5702 - val_accuracy: 0.8093
# Epoch 11/50
# 439/439 - 88s - loss: 0.6177 - accuracy: 0.7838 - val_loss: 0.8077 - val_accuracy: 0.7003
# Epoch 12/50
# 439/439 - 88s - loss: 0.5915 - accuracy: 0.7992 - val_loss: 0.6308 - val_accuracy: 0.7993
# Epoch 13/50
# 439/439 - 90s - loss: 0.5097 - accuracy: 0.8263 - val_loss: 0.4263 - val_accuracy: 0.8610
# Epoch 14/50
# 439/439 - 90s - loss: 0.4905 - accuracy: 0.8303 - val_loss: 0.3838 - val_accuracy: 0.8690
# Epoch 15/50
# 439/439 - 89s - loss: 0.4800 - accuracy: 0.8358 - val_loss: 0.3965 - val_accuracy: 0.8650
# Epoch 16/50
# 439/439 - 88s - loss: 0.4617 - accuracy: 0.8445 - val_loss: 0.3940 - val_accuracy: 0.8707
# Epoch 17/50
# 439/439 - 90s - loss: 0.4525 - accuracy: 0.8436 - val_loss: 0.3888 - val_accuracy: 0.8713
# Epoch 18/50
# 439/439 - 89s - loss: 0.4418 - accuracy: 0.8466 - val_loss: 0.4060 - val_accuracy: 0.8630
# Epoch 19/50
# 439/439 - 88s - loss: 0.4378 - accuracy: 0.8487 - val_loss: 0.3864 - val_accuracy: 0.8717
# Epoch 20/50
# 439/439 - 88s - loss: 0.4073 - accuracy: 0.8624 - val_loss: 0.3620 - val_accuracy: 0.8777
# Epoch 21/50
# 439/439 - 89s - loss: 0.4030 - accuracy: 0.8613 - val_loss: 0.3483 - val_accuracy: 0.8820
# Epoch 22/50
# 439/439 - 88s - loss: 0.3947 - accuracy: 0.8638 - val_loss: 0.3484 - val_accuracy: 0.8880
# Epoch 23/50
# 439/439 - 88s - loss: 0.3893 - accuracy: 0.8660 - val_loss: 0.3327 - val_accuracy: 0.8907
# Epoch 24/50
# 439/439 - 88s - loss: 0.3844 - accuracy: 0.8670 - val_loss: 0.3671 - val_accuracy: 0.8810
# Epoch 25/50
# 439/439 - 88s - loss: 0.3911 - accuracy: 0.8645 - val_loss: 0.4055 - val_accuracy: 0.8707
# Epoch 26/50
# 439/439 - 88s - loss: 0.3819 - accuracy: 0.8694 - val_loss: 0.3819 - val_accuracy: 0.8753
# Epoch 27/50
# 439/439 - 87s - loss: 0.3798 - accuracy: 0.8682 - val_loss: 0.3442 - val_accuracy: 0.8897
# Epoch 28/50
# 439/439 - 88s - loss: 0.3816 - accuracy: 0.8671 - val_loss: 0.3337 - val_accuracy: 0.8897
# Epoch 29/50
# 439/439 - 88s - loss: 0.3750 - accuracy: 0.8753 - val_loss: 0.3381 - val_accuracy: 0.8903
# Epoch 30/50
# 439/439 - 88s - loss: 0.3641 - accuracy: 0.8730 - val_loss: 0.3292 - val_accuracy: 0.8937
# Epoch 31/50
# 439/439 - 87s - loss: 0.3673 - accuracy: 0.8754 - val_loss: 0.3334 - val_accuracy: 0.8910
# Epoch 32/50
# 439/439 - 89s - loss: 0.3453 - accuracy: 0.8808 - val_loss: 0.3366 - val_accuracy: 0.8910
# Epoch 33/50
# 439/439 - 89s - loss: 0.3571 - accuracy: 0.8809 - val_loss: 0.3326 - val_accuracy: 0.8913
# Epoch 34/50
# 439/439 - 88s - loss: 0.3577 - accuracy: 0.8776 - val_loss: 0.3489 - val_accuracy: 0.8897
# Epoch 35/50
# 439/439 - 88s - loss: 0.3513 - accuracy: 0.8794 - val_loss: 0.3300 - val_accuracy: 0.8933
# Epoch 36/50
# 439/439 - 90s - loss: 0.3549 - accuracy: 0.8777 - val_loss: 0.3273 - val_accuracy: 0.8920
# Epoch 37/50
# 439/439 - 89s - loss: 0.3504 - accuracy: 0.8803 - val_loss: 0.3281 - val_accuracy: 0.8923
# Epoch 38/50
# 439/439 - 89s - loss: 0.3494 - accuracy: 0.8802 - val_loss: 0.3319 - val_accuracy: 0.8913
# Epoch 39/50
# 439/439 - 90s - loss: 0.3518 - accuracy: 0.8778 - val_loss: 0.3263 - val_accuracy: 0.8900
# Epoch 40/50
# 439/439 - 89s - loss: 0.3568 - accuracy: 0.8754 - val_loss: 0.3246 - val_accuracy: 0.8913
# Epoch 41/50
# 439/439 - 89s - loss: 0.3474 - accuracy: 0.8786 - val_loss: 0.3224 - val_accuracy: 0.8937
# Epoch 42/50
# 439/439 - 88s - loss: 0.3506 - accuracy: 0.8799 - val_loss: 0.3263 - val_accuracy: 0.8933
# Epoch 43/50
# 439/439 - 88s - loss: 0.3473 - accuracy: 0.8792 - val_loss: 0.3237 - val_accuracy: 0.8933
# Epoch 44/50
# 439/439 - 89s - loss: 0.3491 - accuracy: 0.8806 - val_loss: 0.3220 - val_accuracy: 0.8953
# Epoch 45/50
# 439/439 - 89s - loss: 0.3490 - accuracy: 0.8816 - val_loss: 0.3242 - val_accuracy: 0.8927
# Epoch 46/50
# 439/439 - 88s - loss: 0.3483 - accuracy: 0.8789 - val_loss: 0.3232 - val_accuracy: 0.8940
# Epoch 47/50
# 439/439 - 89s - loss: 0.3476 - accuracy: 0.8799 - val_loss: 0.3237 - val_accuracy: 0.8927
# Epoch 48/50
# 439/439 - 89s - loss: 0.3428 - accuracy: 0.8829 - val_loss: 0.3244 - val_accuracy: 0.8923
# Epoch 49/50
# 439/439 - 89s - loss: 0.3516 - accuracy: 0.8814 - val_loss: 0.3332 - val_accuracy: 0.8913
# Epoch 50/50
# 439/439 - 88s - loss: 0.3438 - accuracy: 0.8805 - val_loss: 0.3255 - val_accuracy: 0.8920

# %% [markdown]
# #### **i. Plotting training and validation accuracy, loss and learning rate**

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **6. Testing the Model on Test Set**

# %%
test_dataset = '/kaggle/input/intel-image-classification/seg_test/seg_test/'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 3000 images belonging to 6 classes.

# %% [markdown]
# ### **7. Model Prediction on the Test Dataset**

# %%
predictions = cnn_model.predict(test_generator)

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
test_loss, test_accuracy = cnn_model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 94/94 [==============================] - 4s 47ms/step - loss: 0.3255 - accuracy: 0.8920

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Test Loss:     0.3254610300064087
# Test Accuracy: 0.8920000195503235

# %% [markdown]
# ### **8. Plotting the Classification Metrics**

# %% [markdown]
# ### **i. Confusion Matrix**

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(6, 6)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#    buildings       0.84      0.91      0.87       437
#       forest       0.97      0.98      0.98       474
#      glacier       0.87      0.83      0.85       553
#     mountain       0.86      0.85      0.85       525
#          sea       0.90      0.92      0.91       510
#       street       0.91      0.88      0.89       501
#
#     accuracy                           0.89      3000
#    macro avg       0.89      0.89      0.89      3000
# weighted avg       0.89      0.89      0.89      3000

# %% [markdown]
# ### **9. Wrong Predictions**
#
# Let's see where the model has given wrong predictions and what were the actual predictions on those images.

# %%
errors = (y_true - y_pred != 0)
y_true_errors = y_true[errors]
y_pred_errors = y_pred[errors]

# %%
test_images = test_generator.filenames
test_img = np.asarray(test_images)[errors]

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        idx = np.random.randint(0, len(test_img))
        true_index = y_true_errors[idx]
        true_label = labels[true_index]
        predicted_index = y_pred_errors[idx]
        predicted_label = labels[predicted_index]
        ax[i, j].set_title(f"True Label: {true_label} \n Predicted Label: {predicted_label}")
        img_path = os.path.join(test_dataset, test_img[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax[i, j].imshow(img)
        ax[i, j].axis("off")

plt.tight_layout()
plt.suptitle('Wrong Predictions made on test set', fontsize=20)
plt.show()
